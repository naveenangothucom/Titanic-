# %% [markdown]
# import packages

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('train.csv')
data.head(20)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# ...

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
data.shape
# Out:
# (891, 12)

# %%
data.drop(['PassengerId','Name','Ticket','Cabin'],axis=1,inplace=True)

# %%
data.head(20)
# Out:
#     Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0          0       3    male  22.0      1      0   7.2500        S
# 1          1       1  female  38.0      1      0  71.2833        C
# 2          1       3  female  26.0      0      0   7.9250        S
# 3          1       1  female  35.0      1      0  53.1000        S
# 4          0       3    male  35.0      0      0   8.0500        S
# 5          0       3    male   NaN      0      0   8.4583        Q
# 6          0       1    male  54.0      0      0  51.8625        S
# 7          0       3    male   2.0      3      1  21.0750        S
# 8          1       3  female  27.0      0      2  11.1333        S
# 9          1       2  female  14.0      1      0  30.0708        C
# 10         1       3  female   4.0      1      1  16.7000        S
# 11         1       1  female  58.0      0      0  26.5500        S
# 12         0       3    male  20.0      0      0   8.0500        S
# ...

# %%
data['Age'] = data["Age"].transform(lambda x: x.fillna(x.mean()))

# %%
data.head(20)
# Out:
#     Survived  Pclass     Sex        Age  SibSp  Parch     Fare Embarked
# 0          0       3    male  22.000000      1      0   7.2500        S
# 1          1       1  female  38.000000      1      0  71.2833        C
# 2          1       3  female  26.000000      0      0   7.9250        S
# 3          1       1  female  35.000000      1      0  53.1000        S
# 4          0       3    male  35.000000      0      0   8.0500        S
# 5          0       3    male  29.699118      0      0   8.4583        Q
# 6          0       1    male  54.000000      0      0  51.8625        S
# 7          0       3    male   2.000000      3      1  21.0750        S
# 8          1       3  female  27.000000      0      2  11.1333        S
# 9          1       2  female  14.000000      1      0  30.0708        C
# 10         1       3  female   4.000000      1      1  16.7000        S
# 11         1       1  female  58.000000      0      0  26.5500        S
# ...

# %%
# Dropping the columns having NaN/ values 
data = data.dropna(axis=0)

# %%
data.dtypes
# Out:
# Survived      int64
# Pclass        int64
# Sex          object
# Age         float64
# SibSp         int64
# Parch         int64
# Fare        float64
# Embarked     object
# dtype: object

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
enc = OneHotEncoder(handle_unknown='ignore')

# %%
data
enc.fit(data)
# Out:
# OneHotEncoder(categorical_features=None, categories=None, drop=None,
#               dtype=<class 'numpy.float64'>, handle_unknown='ignore',
#               n_values=None, sparse=True)

# %%
enc.categories

# %%
cat_cols=data.select_dtypes("float64").columns
print(cat_cols)
# Out:
# Index(['Age', 'Fare'], dtype='object')

# %%
for x in cat_cols:
    data[x]= data[x].astype("category")
    data[x]= data[x].cat.codes
print()

# %%
data.head()
# Out:
#    Survived  Pclass     Sex  Age  SibSp  Parch  Fare Embarked
# 0         0       3    male   28      1      0    18        S
# 1         1       1  female   52      1      0   207        C
# 2         1       3  female   34      0      0    41        S
# 3         1       1  female   48      1      0   189        S
# 4         0       3    male   48      0      0    43        S

# %% [markdown]
# DATA VISUALIZATION

# %%
plt.hist(data['Age'],bins=10)
plt.gca().set(title="frequency histogram",ylabel="frequency")
# Out:
# [Text(0, 0.5, 'frequency'), Text(0.5, 1.0, 'frequency histogram')]

# %%
plt.hist(data['Fare'],bins=10)
plt.gca().set(title="frequency histogram",ylabel="frequency")
# Out:
# [Text(0, 0.5, 'frequency'), Text(0.5, 1.0, 'frequency histogram')]

# %%
plt.scatter(data["Age"],data["Fare"])
plt.gca().set(title="frequency histogram",ylabel="frequency")
# Out:
# [Text(0, 0.5, 'frequency'), Text(0.5, 1.0, 'frequency histogram')]

# %%
import matplotlib as plt
# %matplotlib inline
import seaborn as sns

# %%
corrmat=data.corr()
top_corr_features=corrmat.index
# #heat map
g=sns.heatmap(data[top_corr_features].corr(),annot=True,cmap="RdYlGn")

# %%
# IN THIS HEAT MAP THE TWO VARIABLES WHICH AS CORRELATED  WHICH AS 'sibsp' AND 'parch'and age,embarcked  
# survived IS USED FOR FUTURE PRIDICTION

# %%
data.drop(['SibSp','Parch','Age'],axis=1,inplace=True)

# %%
data.head()
# Out:
#    Survived  Pclass     Sex  Fare Embarked
# 0         0       3    male    18        S
# 1         1       1  female   207        C
# 2         1       3  female    41        S
# 3         1       1  female   189        S
# 4         0       3    male    43        S

# %% [markdown]
# DATA PREPROCESS

# %%
data.head(15)
# Out:
#     Survived  Pclass     Sex  Fare Embarked
# 0          0       3    male    18        S
# 1          1       1  female   207        C
# 2          1       3  female    41        S
# 3          1       1  female   189        S
# 4          0       3    male    43        S
# 5          0       3    male    51        Q
# 6          0       1    male   186        S
# 7          0       3    male   124        S
# 8          1       3  female    74        S
# 9          1       2  female   154        C
# 10         1       3  female   110        S
# 11         1       1  female   143        S
# 12         0       3    male    43        S
# 13         0       3    male   158        S
# 14         0       3  female    36        S

# %%
# Dropping the columns having NaN/ values 
data = data.dropna(axis=0)

# %%
data.head()
# Out:
#    Survived  Pclass     Sex  Fare Embarked
# 0         0       3    male    18        S
# 1         1       1  female   207        C
# 2         1       3  female    41        S
# 3         1       1  female   189        S
# 4         0       3    male    43        S

# %%
data.dtypes
# Out:
# Survived     int64
# Pclass       int64
# Sex         object
# Fare         int16
# Embarked    object
# dtype: object

# %%
# from sklearn.preprocessing import OneHotEncoder

# %%
# enc = OneHotEncoder(handle_unknown='ignore')

# %%
# data
# enc.fit(data)

# %%
# enc.categories

# %%
# cat_cols=preprocess_df.select_dtypes("object").columns
# print(cat_cols)

# %%
# for x in cat_cols:
#     preprocess_df[x]= preprocess_df[x].astype("category")
#     preprocess_df[x]= preprocess_df[x].cat.codes
# print()

# %%
preprocess_df.head()
# Out:
#    Survived  Pclass  Fare Embarked
# 0         0       3    18        S
# 1         1       1   207        C
# 2         1       3    41        S
# 3         1       1   189        S
# 4         0       3    43        S

# %%
data.columns
# Out:
# Index(['Survived', 'Pclass', 'Sex', 'Fare', 'Embarked'], dtype='object')

# %%
preprocess_df=data[['Survived','Pclass','Fare','Embarked','Sex']]
preprocess_df.head()
# Out:
#    Survived  Pclass  Fare Embarked     Sex
# 0         0       3    18        S    male
# 1         1       1   207        C  female
# 2         1       3    41        S  female
# 3         1       1   189        S  female
# 4         0       3    43        S    male

# %%
preprocess_df.columns
# Out:
# Index(['Survived', 'Pclass', 'Fare', 'Embarked', 'Sex'], dtype='object')

# %%
x=preprocess_df.iloc[:,0:3]
y=preprocess_df['Survived']
x
# Out:
#      Survived  Pclass  Fare
# 0           0       3    18
# 1           1       1   207
# 2           1       3    41
# 3           1       1   189
# 4           0       3    43
# ..        ...     ...   ...
# 886         0       2    85
# 887         1       1   153
# 888         0       3   131
# 889         1       1   153
# 890         0       3    30
#
# [889 rows x 3 columns]

# %%
y
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 889, dtype: int64

# %%
#splitting the data set into the training set and test set
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y, test_size=0.20,random_state=1)

# %%
x_train
# Out:
#      Survived  Pclass  Fare
# 121         0       3    43
# 687         0       3    70
# 790         0       3    30
# 837         0       3    43
# 659         0       1   230
# ..        ...     ...   ...
# 716         1       1   242
# 768         0       3   133
# 73          0       3    94
# 236         0       2   138
# 37          0       3    43
#
# [711 rows x 3 columns]

# %%
x_test
# Out:
#      Survived  Pclass  Fare
# 387         1       2    85
# 259         1       2   138
# 771         0       3    36
# 208         1       3    30
# 683         0       3   179
# ..        ...     ...   ...
# 499         0       3    33
# 731         0       3   115
# 373         0       1   234
# 588         0       3    43
# 234         0       2    72
#
# [178 rows x 3 columns]

# %%
y_train
# Out:
# 121    0
# 687    0
# 790    0
# 837    0
# 659    0
#       ..
# 716    1
# 768    0
# 73     0
# 236    0
# 37     0
# Name: Survived, Length: 711, dtype: int64

# %%
y_test
# Out:
# 387    1
# 259    1
# 771    0
# 208    1
# 683    0
#       ..
# 499    0
# 731    0
# 373    0
# 588    0
# 234    0
# Name: Survived, Length: 178, dtype: int64

# %%
#fitting the logistic regression to the training set
from sklearn.linear_model import LinearRegression
classifier = LinearRegression(normalize=True)
classifier.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=True)

# %%
# Predicting the Test set results
y_pred = classifier.predict(x_test)

# %%
# Making the Confusion Matrix
from sklearn.metrics import r2_score
cm = r2_score(y_test,y_pred)
cm
# Out:
# 1.0

# %%
y_test
# Out:
# 387    1
# 259    1
# 771    0
# 208    1
# 683    0
#       ..
# 499    0
# 731    0
# 373    0
# 588    0
# 234    0
# Name: Survived, Length: 178, dtype: int64

# %%
y_pred
# Out:
# array([ 1.00000000e+00,  1.00000000e+00, -2.23505939e-16,  1.00000000e+00,
#        -1.41140359e-16,  1.00000000e+00,  1.00000000e+00, -1.53236004e-16,
#        -2.34449617e-16,  1.00000000e+00, -4.82957931e-17, -1.90098921e-16,
#         1.00000000e+00,  1.00000000e+00, -2.21202007e-16, -2.05650464e-16,
#        -2.35025601e-16,  1.00000000e+00,  1.00000000e+00, -2.92883517e-17,
#         1.00000000e+00,  1.00000000e+00, -1.16893425e-16, -1.41140359e-16,
#        -3.10163009e-17, -2.06802430e-16,  1.00000000e+00, -2.09682345e-16,
#        -1.81459175e-16,  1.00000000e+00, -2.19474058e-16,  1.00000000e+00,
#         1.00000000e+00,  1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#         1.00000000e+00,  1.00000000e+00, -1.20349323e-16, -4.08080132e-17,
#         1.00000000e+00, -1.20349323e-16, -1.54647579e-17, -2.19474058e-16,
#        -7.30630653e-17,  1.00000000e+00,  1.00000000e+00, -1.20349323e-16,
# ...

# %%
# Fitting Logistic Regression to the Training set
from sklearn.linear_model import LinearRegression
classifier = LinearRegression(normalize=True)
classifier.fit(x_train, y_train)
